# %% [markdown]
# # 任务:对常见的宠物皮肤病进行分类

# %% [markdown]
# ## 导入工具包

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
import torch.optim as optim
import torchvision
from PIL import Image
from torchvision import transforms,models,datasets
import imageio
import time
import warnings
import random
import sys
import copy
import json
from torch.utils.tensorboard import SummaryWriter # Tensorboard可视化训练过程

plt.rcParams['font.sans-serif'] = ['SimHei'] # matplotlib需要设置中文font

# %% [markdown]
# ## 数据读取与预处理操作（----这里面的路径需要改，改为存放图片的路径---）

# %%
data_dir = './data' # root目录
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'

# %% [markdown]
# ## 制作数据源
# - data_transforms中指定了所有图像预处理操作
# - ImageFolder假设所有的文件按文件夹保存好，每个文件夹下面存储同一类别的图片，文件夹的名字为分类的名字
# - ImageFolder具体格式可以参考PyTorch官网
# - 预处理部分进行了数据增强（Data Augmentation）：通过旋转翻转等方法获取更多的数据

# %%
data_transforms = {
    # 训练集进行数据增强操作--->解决数据量较少问题
    'train': transforms.Compose([
        transforms.RandomRotation(90), # 随机旋转，-90度到90度之间
        transforms.CenterCrop(224),  # 从中心开始裁剪    ResNet要求输入的数据为224*224
        transforms.RandomHorizontalFlip(p=0.5), # 随机水平翻转 p为是否翻转的概率
        transforms.RandomVerticalFlip(p=0.5), # 随机垂直翻转
        transforms.ColorJitter(brightness=0.2, contrast=0.1, saturation=0.1, hue=0.1), # 亮度，对比度，饱和度，色相
        transforms.RandomGrayscale(p=0.025), # 概率转换为灰度图，3通道就是RGB
        transforms.ToTensor(), # 转换为Tensor格式
        transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225]) # 标准化：均值，标准差，数值为实验常用
    ]),
    # 验证集不需要进行数据增强
    'valid':transforms.Compose([
        transforms.RandomRotation(90),
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225]),
    ])
}
data_transforms
# Out:
# {'train': Compose(
#      RandomRotation(degrees=[-90.0, 90.0], interpolation=nearest, expand=False, fill=0)
#      CenterCrop(size=(224, 224))
#      RandomHorizontalFlip(p=0.5)
#      RandomVerticalFlip(p=0.5)
#      ColorJitter(brightness=[0.8, 1.2], contrast=[0.9, 1.1], saturation=[0.9, 1.1], hue=[-0.1, 0.1])
#      RandomGrayscale(p=0.025)
#      ToTensor()
#      Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#  ),
#  'valid': Compose(
#      RandomRotation(degrees=[-90.0, 90.0], interpolation=nearest, expand=False, fill=0)
#      Resize(size=256, interpolation=bilinear, max_size=None, antialias=None)
#      CenterCrop(size=(224, 224))
#      ToTensor()
#      Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#  )}

# %%
batch_size = 8 # batch_size为一次取出数据的量，建议设为2^n（最好不超过256）

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train','valid']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x],batch_size=batch_size,shuffle=True) for x in ['train','valid']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train','valid']}
class_names = image_datasets['train'].classes

# %%
image_datasets
# Out:
# {'train': Dataset ImageFolder
#      Number of datapoints: 28
#      Root location: ./medicines_data2\train
#      StandardTransform
#  Transform: Compose(
#                 RandomRotation(degrees=[-90.0, 90.0], interpolation=nearest, expand=False, fill=0)
#                 CenterCrop(size=(224, 224))
#                 RandomHorizontalFlip(p=0.5)
#                 RandomVerticalFlip(p=0.5)
#                 ColorJitter(brightness=[0.8, 1.2], contrast=[0.9, 1.1], saturation=[0.9, 1.1], hue=[-0.1, 0.1])
#                 RandomGrayscale(p=0.025)
#                 ToTensor()
#                 Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#             ),
#  'valid': Dataset ImageFolder
#      Number of datapoints: 8
#      Root location: ./medicines_data2\valid
#      StandardTransform
#  Transform: Compose(
#                 RandomRotation(degrees=[-90.0, 90.0], interpolation=nearest, expand=False, fill=0)
#                 Resize(size=256, interpolation=bilinear, max_size=None, antialias=None)
#                 CenterCrop(size=(224, 224))
#                 ToTensor()
#                 Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#             )}

# %%
dataloaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x1d207b0e8f0>,
#  'valid': <torch.utils.data.dataloader.DataLoader at 0x1d207b0fcd0>}

# %%
# 打印一下数据量
dataset_sizes
# Out:
# {'train': 101, 'valid': 38}

# %% [markdown]
# ## 读取标签对应皮肤病的名字（---这里的json文件也要改，改为对应的皮肤病种类---）

# %%
# 如果读取路径有中文名，需加上encoding='utf-8'
with open('info.json','r',encoding='utf-8') as f:
    medicines_to_name = json.load(f)

# %%
data_to_name
# Out:
# {'1': '橘红', '2': '枸杞', '3': '甘草片', '4': '参片', '5': '黄芪'}

# %% [markdown]
# ## 展示数据
# - 注意tensor的数据需要转换为numpy的格式，而且需要还原回标准化的结果

# %%
def im_convert(tensor):
    """展示数据
        将处理后的tensor数据原路转换为numpy格式的数据
    """
    
    image = tensor.to("cpu").clone().detach()
    image = image.numpy().squeeze()
    image = image.transpose(1,2,0) # 因为PyTorch中第一个通道为颜色通道，所以需要使用transpose进行转换，对应位置进行更换(0,1,2)-->(1,2,0)
    image = image * np.array((0.229,0.224,0.225)) + np.array((0.485,0.456,0.406)) # 逆向归一化处理
    image = image.clip(0,1)
    
    return image

# %%
fig = plt.figure(figsize=(20,12))
columns = 4
rows = 2

dataiter = iter(dataloaders['train'])
inputs,classes = dataiter.__next__()

for idx in range(columns * rows):
    ax = fig.add_subplot(rows,columns,idx+1,xticks=[],yticks=[])
    ax.set_title(medicines_to_name[str(int(class_names[classes[idx]]))])
    plt.imshow(im_convert(inputs[idx]))
plt.show()

# %% [markdown]
# ## 加载models中提供的模块，并且直接用训练好的权重当做初始化参数
# - 第一次执行需要下载，如果过慢，可以直接将文件保存到指定的目录下
# - 我电脑下载的位置C:\Users\22148\.cache\torch\hub\checkpoints
# - 直接将官网下载pth后缀的文件，存入对应目录下即可

# %%
model_name = "resnet"
# 是否用人家训练好的特征来做
feature_extract = True

# %%
# 判断电脑是否能够支持GPU计算
# 我的电脑刚开始可以，后面就不行了，我也不知道为啥...
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available. Training on CPU...不支持GPU')
else:
    print('CUDA is available! Training on GPU...支持GPU')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# CUDA is available! Training on GPU...支持GPU

# %%
"""设置训练过程需要更新的参数，默认中间的网络架构参数不更新"""
# 参考视频我先把函数放在这，用不用以后的事
def set_parameter_requires_grad(model,feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %% [markdown]
# ## （---这里也需要改，我之前用的是152层的ResNet，过拟合且边缘设备算力不够，可以改成34层---）

# %%
# 我参考视频使用了resnet152层的网络，可以换成其他的试试
model_ft = models.resnet152()
# 展示网络
# 说白了就是卷积层，池化层...不断重复
model_ft
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %% [markdown]
# 网络的最后一层为Linear(in_features=2048, out_features=1000, bias=True)，其中out_features为需要分类的类别数量，对应的就是我们要识别的中药数量
# ## 加载模型

# %%
def initialize_model(model_name,num_classes,feature_extract,weights=torchvision.models.ResNet152_Weights.DEFAULT):
    # 选择合适的模型，不同模型的初始化方法有区别
    model_ft = None
    input_size = 0
    
    if model_name == "resnet":
        """Resnet152
        """
        model_ft = models.resnet152(pretrained=True) # pretrained如果指定为True值，运行时并自动帮忙下载，之前的仅仅是网络架构
        set_parameter_requires_grad(model_ft,feature_extract)
        num_ftrs = model_ft.fc.in_features
        output_size = 5 # 设置需要分类的结果数量
        model_ft.fc = nn.Sequential(nn.Linear(num_ftrs,output_size),
                                   nn.LogSoftmax(dim=1) )
        input_size = 224
    """如果使用其他的网络就改变上面的model_name值，并多加几个判断，分支里的代码可以参考PyTorch官网"""
    return model_ft,input_size

# %% [markdown]
# ## 设置哪些层需要训练

# %%
model_ft,input_size = initialize_model(model_name,5,feature_extract)

# %%
# GPU计算
model_ft = model_ft.to(device)

# 模型保存
filename = "C:\\Users\\22148\\Desktop\\Recognition of medicine\\Asunne2.pth"# 双\是为了解决字符转义导致的路径有误，我的电脑需要这样

# 是否训练所有层
params_to_update = model_ft.parameters()
print("Params to learn:") # 打印需要训练的层
if feature_extract:
    params_to_update = []
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            params_to_update.append(param)
            print("\t",name)
else:
    for name,param in model_ft.named_parameters():
        if param.requires_grad == True:
            print("\t",name)
# Out:
# Params to learn:
# 	 fc.0.weight
# 	 fc.0.bias

# %%
model_ft
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=5, bias=True)
#     (1): LogSoftmax(dim=1)
#   )
# )

# %% [markdown]
# ## 优化器设置

# %%
# 优化器设置
"""优化器我参考视频选择了Adam，你们可以使用其他的试试看
    学习率采用了衰减策略，刚开始学习率较大，后面学习率慢慢减小
"""
optimizer_ft = optim.Adam(params_to_update,lr=1e-2)
scheduler = optim.lr_scheduler.StepLR(optimizer_ft,step_size=5,gamma=0.1)
# 最后一层已经LogSoftmax()了，所以不能nn.CrossEntropyLoss()来计算，nn.CrossEntropyLoss()相当于logSoftmax()和nn.NLLLoss整合
criterion = nn.NLLLoss()

# %% [markdown]
# ## 引入Tensorboard，可视化训练过程

# %%
writer = SummaryWriter("logs_train")

# %% [markdown]
# ## 训练模块

# %%
def train_model(model,dataloaders,criterion,optimizer,num_epochs=10,is_inception=False,filename=filename):
    since = time.time() # 记录开始训练的时间
    best_acc = 0
    """
    checkpoint = torch.load(filename)
    best_acc = checkpoint['best_acc']
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    model.class_to_idx = checkpoint['mapping']
    """
    model.to(device)
    
    total_train_step = 0
    total_valid_step = 0
    val_acc_history = []
    train_acc_history = []
    train_losses = []
    valid_losses = []
    LRs = [optimizer.param_groups[0]['lr']]
    
    best_model_wts = copy.deepcopy(model.state_dict())
    
    # 开始迭代训练
    for epoch in range(num_epochs):
        print('正在进行第{}/{}轮训练'.format(epoch,num_epochs-1))
        print('-'*30)
        
        # 训练和验证
        for phase in ['train','valid']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
            running_loss = 0.0
            running_corrects = 0
            
            # 把数据都取个遍
            for inputs,labels in dataloaders[phase]:
                # 将数据读入GPU中进行训练，如果没有GPU，这一步可以舍去
                inputs = inputs.to(device)
                labels = labels.to(device)
                
#                 if phase=='train'
#                 total_train_step += 1
#                 if phase=='valid'
#                 total_valid_step += 1
                
#                 if total_train_step%20==0: # 每20次取数据记录一次
#                     writer.add_scalar("train_loss",)

                # 梯度清零
                optimizer.zero_grad()
                
                # 只有训练的时候计算和更新梯度
                # 参考PyTorch官网写法
                # 大致意思就是指定训练阶段更新梯度，验证阶段不进行更新
                with torch.set_grad_enabled(phase == 'train'):
                    if is_inception and phase == 'train':
                        outputs,aux_outputs = model(inputs)
                        loss1 = criterion(outputs,labels)
                        loss2 = criterion(aux_outputs,labels)
                        loss = loss1 + 0.4*loss2
                    else: # resnet执行此分支
                        outputs = model(inputs)
                        loss = criterion(outputs,labels)
                        
                    _, preds = torch.max(outputs,1)
                        
                    # 训练阶段更新权重
                    if phase == 'train':
                        # 反向传播，梯度更新
                        loss.backward()
                        optimizer.step()
                            
                # 计算损失
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                    
            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects.double() / len(dataloaders[phase].dataset)
                
            time_elapsed = time.time() - since
            # 展示迭代一个epoch需要的时间
            print('Time elapsed {:.0f}s'.format(time_elapsed // 60,time_elapsed % 60))
            print('{}:总损失: {:.4f} 准确率: {:.4f}'.format(phase,epoch_loss,epoch_acc))
            
            # 可视化损失函数的变化
            if phase=='train':
                writer.add_scalar("train2_loss",epoch_loss,epoch)
            if phase=='valid':
                writer.add_scalar("valid2_loss",epoch_loss,epoch)

            # 得到最好那次的模型
            if phase =='valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                # 参考官网写法，复制最好的权重参数
                best_model_wts = copy.deepcopy(model.state_dict(),)
                # 模型保存对应的指标
                state = {
                    'state_dict':model.state_dict(),
                    'best_acc':best_acc,
                    'optimizer':optimizer.state_dict(),
                }
                torch.save(state,filename)
            if phase == 'valid':
                val_acc_history.append(epoch_acc)
                valid_losses.append(epoch_loss)
                scheduler.step(epoch_loss)
            if phase ==' train':
                train_acc_history.append(epoch_acc)
                train_losses.append(epoch_loss)
                    
        print('Optimizer learing rate : {:.7f}'.format(optimizer.param_groups[0]['lr']))
        LRs.append(optimizer.param_groups[0]['lr'])
        print()
            
    time_elapsed = time.time()-since
    print('总训练时长:{:.0f}m {:.0f}s'.format(time_elapsed // 60,time_elapsed%60))
    print('最好的准确率:{:4f}'.format(best_acc))
    
    # 训练完后用最好的一次当做模型最终的结果
    model.load_state_dict(best_model_wts)
    return model,val_acc_history,train_acc_history,valid_losses,train_losses,LRs

# %% [markdown]
# ## 开始训练

# %%
model_ft,val_acc_history,train_acc_history,valid_losses,train_losses,LRs = train_model(model_ft,dataloaders,criterion,optimizer_ft,num_epochs=1000,is_inception=(model_name=='inception'))
# Out:
# 正在进行第0/999轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 5.6960 准确率: 0.2673
# Time elapsed 0s
# valid:总损失: 2.8265 准确率: 0.4211
# C:\Users\22148\.conda\envs\DeepLearning2\lib\site-packages\torch\optim\lr_scheduler.py:163: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Optimizer learing rate : 0.0100000
#
# 正在进行第1/999轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 2.2331 准确率: 0.4257
# Time elapsed 0s
# valid:总损失: 0.7806 准确率: 0.6842
# Optimizer learing rate : 0.0100000
#
# 正在进行第2/999轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.0143 准确率: 0.6832
# Time elapsed 0s
# valid:总损失: 0.7710 准确率: 0.7895
# Optimizer learing rate : 0.0100000
#
# 正在进行第3/999轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.3053 准确率: 0.6238
# Time elapsed 0s
# valid:总损失: 0.4679 准确率: 0.8684
# Optimizer learing rate : 0.0100000
#
# 正在进行第4/999轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.1878 准确率: 0.7327
# Time elapsed 0s
# valid:总损失: 0.5409 准确率: 0.8158
# Optimizer learing rate : 0.0100000
#
# 正在进行第5/999轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 0.7427 准确率: 0.7723
# Time elapsed 0s
# valid:总损失: 0.1793 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第6/999轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 0.6507 准确率: 0.8020
# Time elapsed 0s
# valid:总损失: 0.4441 准确率: 0.7895
# Optimizer learing rate : 0.0100000
#
# 正在进行
准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第209/999轮训练
# ------------------------------
# Time elapsed 7s
# train:总损失: 2.2615 准确率: 0.8515
# Time elapsed 7s
# valid:总损失: 0.0030 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第210/999轮训练
# ------------------------------
# Time elapsed 7s
# train:总损失: 1.5010 准确率: 0.8119
# Time elapsed 7s
# valid:总损失: 0.8197 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第211/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 2.0402 准确率: 0.8119
# Time elapsed 8s
# valid:总损失: 2.6629 准确率: 0.7895
# Optimizer learing rate : 0.0100000
#
# 正在进行第212/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 2.4904 准确率: 0.7921
# Time elapsed 8s
# valid:总损失: 0.2132 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第213/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.5148 准确率: 0.9010
# Time elapsed 8s
# valid:总损失: 0.1212 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第214/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.4337 准确率: 0.9208
# Time elapsed 8s
# valid:总损失: 0.4804 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第215/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.9337 准确率: 0.9010
# Time elapsed 8s
# valid:总损失: 0.1778 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第216/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.5549 准确率: 0.9010
# Time elapsed 8s
# valid:总损失: 0.0348 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第217/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.8497 准确率: 0.8515
# Time elapsed 8s
# valid:总损失: 0.1446 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第218/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 1.4526 准确率: 0.8119
# Time elapsed 8s
# valid:总损失: 0.2368 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第219/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 1.4657 准确率: 0.8218
# Time elapsed 8s
# valid:总损失: 0.1313 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第220/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.8575 准确率: 0.8812
# Time elapsed 8s
# valid:总损失: 0.0123 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第221/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.9956 准确率: 0.8713
# Time elapsed 8s
# valid:总损失: 0.0579 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第222/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 1.0309 准确率: 0.8614
# Time elapsed 8s
# valid:总损失: 0.4537 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第223/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 1.0249 准确率: 0.8218
# Time elapsed 8s
# valid:总损失: 0.2702 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第224/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 1.8273 准确率: 0.8119
# Time elapsed 8s
# valid:总损失: 0.2310 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第225/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 1.4529 准确率: 0.8416
# Time elapsed 8s
# valid:总损失: 0.1692 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第226/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.7333 准确率: 0.8812
# Time elapsed 8s
# valid:总损失: 0.3755 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第227/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.8242 准确率: 0.8812
# Time elapsed 8s
# valid:总损失: 0.0174 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第228/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.7108 准确率: 0.9109
# Time elapsed 8s
# valid:总损失: 0.1676 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第229/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.2888 准确率: 0.9307
# Time elapsed 8s
# valid:总损失: 0.0087 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第230/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.8375 准确率: 0.8911
# Time elapsed 8s
# valid:总损失: 0.2137 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第231/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.4083 准确率: 0.9208
# Time elapsed 8s
# valid:总损失: 0.1069 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第232/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 1.8998 准确率: 0.7327
# Time elapsed 8s
# valid:总损失: 0.8337 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第233/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 2.8035 准确率: 0.7327
# Time elapsed 8s
# valid:总损失: 0.1501 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第234/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.5738 准确率: 0.8812
# Time elapsed 8s
# valid:总损失: 0.0931 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第235/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.6297 准确率: 0.9109
# Time elapsed 8s
# valid:总损失: 0.1386 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第236/999轮训练
# ------------------------------
# Time elapsed 8s
# train:总损失: 0.5950 准确率: 0.9208
# Time elapsed 8s
# valid:总损失: 0.0383 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第237/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.6086 准确率: 0.9010
# Time elapsed 9s
# valid:总损失: 0.1431 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第238/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.1619 准确率: 0.8713
# Time elapsed 9s
# valid:总损失: 0.7551 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第239/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.7120 准确率: 0.9208
# Time elapsed 9s
# valid:总损失: 0.5428 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第240/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.9486 准确率: 0.8614
# Time elapsed 9s
# valid:总损失: 0.5856 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第241/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.5885 准确率: 0.8713
# Time elapsed 9s
# valid:总损失: 0.2647 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第242/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.3131 准确率: 0.7921
# Time elapsed 9s
# valid:总损失: 0.3543 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第243/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 2.4828 准确率: 0.7624
# Time elapsed 9s
# valid:总损失: 0.4398 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第244/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.6957 准确率: 0.8614
# Time elapsed 9s
# valid:总损失: 0.1444 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第245/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.5660 准确率: 0.8416
# Time elapsed 9s
# valid:总损失: 0.7790 准确率: 0.8684
# Optimizer learing rate : 0.0100000
#
# 正在进行第246/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 2.6969 准确率: 0.7822
# Time elapsed 9s
# valid:总损失: 0.0755 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第247/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.4755 准确率: 0.8218
# Time elapsed 9s
# valid:总损失: 0.1046 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第248/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.3235 准确率: 0.8713
# Time elapsed 9s
# valid:总损失: 0.2238 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第249/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.0542 准确率: 0.8119
# Time elapsed 9s
# valid:总损失: 0.4085 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第250/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.0735 准确率: 0.8317
# Time elapsed 9s
# valid:总损失: 0.1683 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第251/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.9280 准确率: 0.9109
# Time elapsed 9s
# valid:总损失: 0.0015 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第252/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.9788 准确率: 0.8515
# Time elapsed 9s
# valid:总损失: 0.4084 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第253/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.0801 准确率: 0.8812
# Time elapsed 9s
# valid:总损失: 0.3199 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第254/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.2680 准确率: 0.8614
# Time elapsed 9s
# valid:总损失: 0.0401 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第255/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.5843 准确率: 0.9307
# Time elapsed 9s
# valid:总损失: 0.0858 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第256/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.4419 准确率: 0.9307
# Time elapsed 9s
# valid:总损失: 0.8630 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第257/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.9269 准确率: 0.8713
# Time elapsed 9s
# valid:总损失: 0.0415 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第258/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.5889 准确率: 0.8317
# Time elapsed 9s
# valid:总损失: 0.4836 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第259/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 1.9827 准确率: 0.8317
# Time elapsed 9s
# valid:总损失: 0.3392 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第260/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.3560 准确率: 0.9406
# Time elapsed 9s
# valid:总损失: 0.0960 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第261/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.7659 准确率: 0.9010
# Time elapsed 9s
# valid:总损失: 0.1500 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第262/999轮训练
# ------------------------------
# Time elapsed 9s
# train:总损失: 0.7229 准确率: 0.9010
# Time elapsed 10s
# valid:总损失: 0.4642 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第263/999轮训练
# ------------------------------
# Time elapsed 10s
# train:总损失: 0.8464 准确率: 0.9307
# Time elapsed 10s
# valid:总损失: 0.2066 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第264/999轮训练
# ------------------------------
# Time elapsed 10s
# train:总损失: 0.9814 准确率: 0.9010
# Time elapsed 10s
# valid:总损失: 0.0000 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第265/999轮训练
# ------------------------------
# Time elapsed 10s
# train:总损失: 1.0868 准确率: 0.8416
# Time elapsed 10s
# valid:总损失: 0.6478 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第266/999轮训练
# ------------------------------
# Time elapsed 10s
# train:总损失: 1.1775 准确率: 0.8812
# Time elapsed 10s
# valid:总损失: 0.0242 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第267/999轮训练
# ------------------------------
# Time elapsed 10s
# train:总损失: 0.6317 准确率: 0.9010
# Time elapsed 10s
# valid:总损失: 0.0990 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第268/999轮训练
# ------------------------------
# Time elapsed 10s
# train:总损失: 0.9858 准确率: 0.8911
# Time elapsed 10s
# valid:总损失: 0.1028 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第269/999轮训练
# ------------------------------
# Time elapsed 10s
# train:总损失: 0.3620 准确率: 0.9208
# Time elapsed 10s
# valid:总损失: 0.8273 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第270/999轮训练
# ------------------------------
# Time elapsed 10s
# train:总损失: 1.0163 准确率: 0.8515
# Time elapsed 10s
# valid:总损失: 0.0000 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第271/999轮训练
# ------------------------------
# Time elapsed 10s
# train:总损失: 1.3047 准确率: 0.8713
# ...
# Optimizer learing rate : 0.0100000
#
# 正在进行第910/999轮训练
# ------------------------------
# Time elapsed 36s
# train:总损失: 0.2747 准确率: 0.9604
# Time elapsed 36s
# valid:总损失: 0.2168 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第911/999轮训练
# ------------------------------
# Time elapsed 36s
# train:总损失: 1.1718 准确率: 0.8812
# Time elapsed 36s
# valid:总损失: 0.0037 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第912/999轮训练
# ------------------------------
# Time elapsed 36s
# train:总损失: 1.2968 准确率: 0.9010
# Time elapsed 36s
# valid:总损失: 0.0000 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第913/999轮训练
# ------------------------------
# Time elapsed 36s
# train:总损失: 0.9267 准确率: 0.9208
# Time elapsed 36s
# valid:总损失: 0.2195 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第914/999轮训练
# ------------------------------
# Time elapsed 36s
# train:总损失: 0.6647 准确率: 0.9109
# Time elapsed 36s
# valid:总损失: 0.1659 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第915/999轮训练
# ------------------------------
# Time elapsed 36s
# train:总损失: 0
999轮训练
# ------------------------------
# Time elapsed 37s
# train:总损失: 1.6326 准确率: 0.8812
# Time elapsed 37s
# valid:总损失: 0.0378 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第953/999轮训练
# ------------------------------
# Time elapsed 37s
# train:总损失: 0.9057 准确率: 0.9406
# Time elapsed 37s
# valid:总损失: 0.2257 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第954/999轮训练
# ------------------------------
# Time elapsed 37s
# train:总损失: 0.9392 准确率: 0.9208
# Time elapsed 37s
# valid:总损失: 0.2443 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第955/999轮训练
# ------------------------------
# Time elapsed 37s
# train:总损失: 0.5481 准确率: 0.9307
# Time elapsed 37s
# valid:总损失: 0.3605 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第956/999轮训练
# ------------------------------
# Time elapsed 37s
# train:总损失: 0.9669 准确率: 0.9208
# Time elapsed 37s
# valid:总损失: 0.9899 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第957/999轮训练
# ------------------------------
# Time elapsed 37s
# train:总损失: 1.5673 准确率: 0.9010
# Time elapsed 38s
# valid:总损失: 0.0005 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第958/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.9049 准确率: 0.9010
# Time elapsed 38s
# valid:总损失: 0.0113 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第959/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 1.0441 准确率: 0.8812
# Time elapsed 38s
# valid:总损失: 0.0218 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第960/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.5942 准确率: 0.9406
# Time elapsed 38s
# valid:总损失: 1.3804 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第961/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 1.5457 准确率: 0.9010
# Time elapsed 38s
# valid:总损失: 0.3434 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第962/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.9843 准确率: 0.8812
# Time elapsed 38s
# valid:总损失: 0.0108 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第963/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 1.3307 准确率: 0.8911
# Time elapsed 38s
# valid:总损失: 0.0000 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第964/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.3017 准确率: 0.9703
# Time elapsed 38s
# valid:总损失: 0.0000 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第965/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.7132 准确率: 0.9307
# Time elapsed 38s
# valid:总损失: 0.0000 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第966/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.6618 准确率: 0.9307
# Time elapsed 38s
# valid:总损失: 0.6072 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第967/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.8225 准确率: 0.9406
# Time elapsed 38s
# valid:总损失: 0.0000 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第968/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.4145 准确率: 0.9208
# Time elapsed 38s
# valid:总损失: 0.0894 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第969/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 2.0002 准确率: 0.8713
# Time elapsed 38s
# valid:总损失: 0.4275 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第970/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 1.1865 准确率: 0.9208
# Time elapsed 38s
# valid:总损失: 0.0450 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第971/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 1.2827 准确率: 0.8614
# Time elapsed 38s
# valid:总损失: 0.0442 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第972/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 1.1328 准确率: 0.9010
# Time elapsed 38s
# valid:总损失: 0.0060 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第973/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.1674 准确率: 0.9604
# Time elapsed 38s
# valid:总损失: 0.3970 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第974/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.5572 准确率: 0.9406
# Time elapsed 38s
# valid:总损失: 0.0009 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第975/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.5681 准确率: 0.9307
# Time elapsed 38s
# valid:总损失: 0.0001 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第976/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.3744 准确率: 0.9604
# Time elapsed 38s
# valid:总损失: 0.1499 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第977/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.0776 准确率: 0.9802
# Time elapsed 38s
# valid:总损失: 0.2620 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第978/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 1.0903 准确率: 0.8515
# Time elapsed 38s
# valid:总损失: 0.1683 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第979/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.5514 准确率: 0.9406
# Time elapsed 38s
# valid:总损失: 0.0023 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第980/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.7208 准确率: 0.9208
# Time elapsed 38s
# valid:总损失: 0.0000 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第981/999轮训练
# ------------------------------
# Time elapsed 38s
# train:总损失: 0.8096 准确率: 0.9307
# Time elapsed 38s
# valid:总损失: 0.0000 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第982/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.1065 准确率: 0.9307
# Time elapsed 39s
# valid:总损失: 0.8381 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第983/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 0.5620 准确率: 0.9307
# Time elapsed 39s
# valid:总损失: 0.1330 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第984/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.2839 准确率: 0.8911
# Time elapsed 39s
# valid:总损失: 0.0003 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第985/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 0.1548 准确率: 0.9505
# Time elapsed 39s
# valid:总损失: 0.0032 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第986/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.1442 准确率: 0.9109
# Time elapsed 39s
# valid:总损失: 0.1495 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第987/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 0.4195 准确率: 0.9307
# Time elapsed 39s
# valid:总损失: 0.2210 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第988/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.4272 准确率: 0.8713
# Time elapsed 39s
# valid:总损失: 1.3222 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第989/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.0081 准确率: 0.9307
# Time elapsed 39s
# valid:总损失: 0.5245 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第990/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.0515 准确率: 0.9010
# Time elapsed 39s
# valid:总损失: 0.8952 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第991/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 0.9822 准确率: 0.9109
# Time elapsed 39s
# valid:总损失: 0.0000 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第992/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 2.4502 准确率: 0.8416
# Time elapsed 39s
# valid:总损失: 0.8735 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第993/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.7133 准确率: 0.9010
# Time elapsed 39s
# valid:总损失: 0.0296 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第994/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.0484 准确率: 0.9010
# Time elapsed 39s
# valid:总损失: 0.0135 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第995/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 0.9349 准确率: 0.9109
# Time elapsed 39s
# valid:总损失: 0.0237 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第996/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.1393 准确率: 0.9010
# Time elapsed 39s
# valid:总损失: 0.5504 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第997/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.5096 准确率: 0.9109
# Time elapsed 39s
# valid:总损失: 0.0002 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第998/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 1.1813 准确率: 0.9307
# Time elapsed 39s
# valid:总损失: 0.0105 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第999/999轮训练
# ------------------------------
# Time elapsed 39s
# train:总损失: 0.6882 准确率: 0.9208
# Time elapsed 39s
# valid:总损失: 0.1210 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 总训练时长:39m 43s
# 最好的准确率:1.000000

# %% [markdown]
# ## 再继续训练所有层

# %%
for param in model_ft.parameters():
    param.requires_grad = True
    
# 再继续训练所有的参数，学习率调小一点
optimizer=optim.Adam(params_to_update,lr=1e-4)
scheduler=optim.lr_scheduler.StepLR(optimizer_ft,step_size=5,gamma=0.1)

# 损失函数
criterion = nn.NLLLoss()

# %%
#Load the checkpoing

checkpoint = torch.load(filename)
best_acc = checkpoint['best_acc']
model_ft.load_state_dict(checkpoint['state_dict'])
optimizer.load_state_dict(checkpoint['optimizer'])
#model_ft.class_to_idx = checkpoint['mapping']

# %%
model_ft,val_acc_history,train_acc_history,valid_losses,train_losses,LRs = train_model(model_ft,dataloaders,criterion,optimizer_ft,num_epochs=100,is_inception=(model_name=='inception'))
# Out:
# 正在进行第0/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.2547 准确率: 0.7921
# Time elapsed 0s
# valid:总损失: 0.7638 准确率: 0.8684
# Optimizer learing rate : 0.0100000
#
# 正在进行第1/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.6375 准确率: 0.7822
# Time elapsed 0s
# valid:总损失: 0.4296 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第2/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.8335 准确率: 0.7030
# Time elapsed 0s
# valid:总损失: 0.6557 准确率: 0.8158
# Optimizer learing rate : 0.0100000
#
# 正在进行第3/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 3.6548 准确率: 0.6337
# Time elapsed 0s
# valid:总损失: 0.3270 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第4/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 4.8591 准确率: 0.6139
# Time elapsed 0s
# valid:总损失: 3.3429 准确率: 0.5789
# Optimizer learing rate : 0.0100000
#
# 正在进行第5/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.3466 准确率: 0.8020
# Time elapsed 0s
# valid:总损失: 0.1014 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第6/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.7311 准确率: 0.7723
# Time elapsed 0s
# valid:总损失: 0.2315 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第7/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 2.5944 准确率: 0.7624
# Time elapsed 0s
# valid:总损失: 1.2107 准确率: 0.7895
# Optimizer learing rate : 0.0100000
#
# 正在进行第8/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 3.9075 准确率: 0.7129
# Time elapsed 0s
# valid:总损失: 0.2318 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第9/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 3.5048 准确率: 0.6634
# Time elapsed 0s
# valid:总损失: 1.5667 准确率: 0.7105
# Optimizer learing rate : 0.0100000
#
# 正在进行第10/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.7562 准确率: 0.8119
# Time elapsed 0s
# valid:总损失: 0.2196 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第11/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.6082 准确率: 0.7426
# Time elapsed 0s
# valid:总损失: 0.7764 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第12/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.6027 准确率: 0.8317
# Time elapsed 0s
# valid:总损失: 0.2372 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第13/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 1.3148 准确率: 0.7624
# Time elapsed 0s
# valid:总损失: 0.1036 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第14/99轮训练
# ------------------------------
# Time elapsed 0s
# train:总损失: 2.2059 准确率: 0.6931
# Time elapsed 0s
# valid:总损失: 1.3593 准确率: 0.7895
# Optimizer learing rate : 0.0100000
#
# 正在进行第15/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 4.6042 准确率: 0.6832
# Time elapsed 1s
# valid:总损失: 0.7167 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第16/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 1.5424 准确率: 0.7921
# Time elapsed 1s
# valid:总损失: 1.0725 准确率: 0.7632
# Optimizer learing rate : 0.0100000
#
# 正在进行第17/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 2.0272 准确率: 0.7921
# Time elapsed 1s
# valid:总损失: 0.1475 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第18/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 0.7910 准确率: 0.8812
# Time elapsed 1s
# valid:总损失: 0.2275 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第19/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 1.3739 准确率: 0.8020
# Time elapsed 1s
# valid:总损失: 0.1785 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第20/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 1.4192 准确率: 0.8020
# Time elapsed 1s
# valid:总损失: 0.4734 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第21/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 0.8761 准确率: 0.8812
# Time elapsed 1s
# valid:总损失: 1.0717 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第22/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 0.9916 准确率: 0.8515
# Time elapsed 1s
# valid:总损失: 0.5231 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第23/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 1.2237 准确率: 0.8218
# Time elapsed 1s
# valid:总损失: 0.4568 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第24/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 1.3912 准确率: 0.8416
# Time elapsed 1s
# valid:总损失: 0.0083 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第25/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 1.1376 准确率: 0.8020
# Time elapsed 1s
# valid:总损失: 0.2237 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第26/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 0.6137 准确率: 0.8812
# Time elapsed 1s
# valid:总损失: 0.5241 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第27/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 1.2874 准确率: 0.8515
# Time elapsed 1s
# valid:总损失: 0.4944 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第28/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 2.1301 准确率: 0.8218
# Time elapsed 1s
# valid:总损失: 0.3085 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第29/99轮训练
# ------------------------------
# Time elapsed 1s
# train:总损失: 1.5680 准确率: 0.8119
# Time elapsed 2s
# valid:总损失: 0.0337 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第30/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 1.9363 准确率: 0.8416
# Time elapsed 2s
# valid:总损失: 1.2869 准确率: 0.8158
# Optimizer learing rate : 0.0100000
#
# 正在进行第31/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 3.0176 准确率: 0.7129
# Time elapsed 2s
# valid:总损失: 0.4763 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第32/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 2.2920 准确率: 0.7426
# Time elapsed 2s
# valid:总损失: 0.5583 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第33/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 1.2700 准确率: 0.8416
# Time elapsed 2s
# valid:总损失: 0.5788 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第34/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 1.3806 准确率: 0.8218
# Time elapsed 2s
# valid:总损失: 0.0104 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第35/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 0.9543 准确率: 0.9010
# Time elapsed 2s
# valid:总损失: 0.1635 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第36/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 1.3066 准确率: 0.8416
# Time elapsed 2s
# valid:总损失: 1.3623 准确率: 0.8421
# Optimizer learing rate : 0.0100000
#
# 正在进行第37/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 3.1718 准确率: 0.8020
# Time elapsed 2s
# valid:总损失: 0.8886 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第38/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 2.1610 准确率: 0.7921
# Time elapsed 2s
# valid:总损失: 1.0666 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第39/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 0.7489 准确率: 0.9208
# Time elapsed 2s
# valid:总损失: 0.7233 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第40/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 1.2492 准确率: 0.8713
# Time elapsed 2s
# valid:总损失: 0.0471 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第41/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 1.0342 准确率: 0.8515
# Time elapsed 2s
# valid:总损失: 0.3949 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第42/99轮训练
# ------------------------------
# Time elapsed 2s
# train:总损失: 1.6341 准确率: 0.8020
# Time elapsed 2s
# valid:总损失: 2.1260 准确率: 0.8421
# Optimizer learing rate : 0.0100000
#
# 正在进行第43/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 1.7662 准确率: 0.8416
# Time elapsed 3s
# valid:总损失: 1.9344 准确率: 0.7895
# Optimizer learing rate : 0.0100000
#
# 正在进行第44/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 3.4113 准确率: 0.7525
# Time elapsed 3s
# valid:总损失: 0.6171 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第45/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 0.7505 准确率: 0.8515
# Time elapsed 3s
# valid:总损失: 0.5852 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第46/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 1.0280 准确率: 0.8911
# Time elapsed 3s
# valid:总损失: 0.1990 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第47/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 0.6767 准确率: 0.9010
# Time elapsed 3s
# valid:总损失: 0.1751 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第48/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 0.7657 准确率: 0.8812
# Time elapsed 3s
# valid:总损失: 0.5286 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第49/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 0.9983 准确率: 0.9109
# Time elapsed 3s
# valid:总损失: 0.0356 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第50/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 0.2458 准确率: 0.9703
# Time elapsed 3s
# valid:总损失: 0.3402 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第51/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 0.2204 准确率: 0.9010
# Time elapsed 3s
# valid:总损失: 0.3781 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第52/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 0.6927 准确率: 0.8812
# Time elapsed 3s
# valid:总损失: 0.0025 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第53/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 1.1201 准确率: 0.8911
# Time elapsed 3s
# valid:总损失: 0.0376 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第54/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 1.5275 准确率: 0.8218
# Time elapsed 3s
# valid:总损失: 0.4650 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第55/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 2.3387 准确率: 0.8218
# Time elapsed 3s
# valid:总损失: 0.8960 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第56/99轮训练
# ------------------------------
# Time elapsed 3s
# train:总损失: 0.8323 准确率: 0.8911
# Time elapsed 3s
# valid:总损失: 0.3065 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第57/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 0.6802 准确率: 0.8911
# Time elapsed 4s
# valid:总损失: 0.0503 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第58/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 0.7007 准确率: 0.9010
# Time elapsed 4s
# valid:总损失: 0.3419 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第59/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 0.4754 准确率: 0.9406
# Time elapsed 4s
# valid:总损失: 0.4726 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第60/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 1.2608 准确率: 0.8416
# Time elapsed 4s
# valid:总损失: 1.2327 准确率: 0.8684
# Optimizer learing rate : 0.0100000
#
# 正在进行第61/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 0.7391 准确率: 0.8812
# Time elapsed 4s
# valid:总损失: 0.4085 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第62/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 0.8640 准确率: 0.9109
# Time elapsed 4s
# valid:总损失: 0.0157 准确率: 1.0000
# Optimizer learing rate : 0.0100000
#
# 正在进行第63/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 2.0002 准确率: 0.8713
# Time elapsed 4s
# valid:总损失: 1.8903 准确率: 0.8421
# Optimizer learing rate : 0.0100000
#
# 正在进行第64/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 2.1244 准确率: 0.8020
# Time elapsed 4s
# valid:总损失: 0.1013 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第65/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 1.4242 准确率: 0.8515
# Time elapsed 4s
# valid:总损失: 2.0312 准确率: 0.8684
# Optimizer learing rate : 0.0100000
#
# 正在进行第66/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 1.0172 准确率: 0.8911
# Time elapsed 4s
# valid:总损失: 0.9301 准确率: 0.8684
# Optimizer learing rate : 0.0100000
#
# 正在进行第67/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 0.9153 准确率: 0.9109
# Time elapsed 4s
# valid:总损失: 0.7018 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第68/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 0.8210 准确率: 0.9010
# Time elapsed 4s
# valid:总损失: 0.4369 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第69/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 0.9305 准确率: 0.8515
# Time elapsed 4s
# valid:总损失: 1.0122 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第70/99轮训练
# ------------------------------
# Time elapsed 4s
# train:总损失: 1.1849 准确率: 0.9109
# Time elapsed 4s
# valid:总损失: 0.6069 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第71/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 0.7044 准确率: 0.8713
# Time elapsed 5s
# valid:总损失: 0.2515 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第72/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 0.5579 准确率: 0.8812
# Time elapsed 5s
# valid:总损失: 0.0905 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第73/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 0.5964 准确率: 0.9307
# Time elapsed 5s
# valid:总损失: 0.1912 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第74/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 0.3889 准确率: 0.9604
# Time elapsed 5s
# valid:总损失: 0.5146 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第75/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 0.9299 准确率: 0.8317
# Time elapsed 5s
# valid:总损失: 0.0685 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第76/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 1.8406 准确率: 0.8020
# Time elapsed 5s
# valid:总损失: 1.7831 准确率: 0.8158
# Optimizer learing rate : 0.0100000
#
# 正在进行第77/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 0.5298 准确率: 0.8812
# Time elapsed 5s
# valid:总损失: 0.5236 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第78/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 2.2218 准确率: 0.7822
# Time elapsed 5s
# valid:总损失: 0.1710 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第79/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 1.8358 准确率: 0.8020
# Time elapsed 5s
# valid:总损失: 0.6374 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第80/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 1.4077 准确率: 0.8218
# Time elapsed 5s
# valid:总损失: 1.3818 准确率: 0.8158
# Optimizer learing rate : 0.0100000
#
# 正在进行第81/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 1.4316 准确率: 0.8614
# Time elapsed 5s
# valid:总损失: 0.2386 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第82/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 0.8127 准确率: 0.9010
# Time elapsed 5s
# valid:总损失: 0.2520 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第83/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 0.9565 准确率: 0.8911
# Time elapsed 5s
# valid:总损失: 0.5514 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第84/99轮训练
# ------------------------------
# Time elapsed 5s
# train:总损失: 1.2313 准确率: 0.8614
# Time elapsed 5s
# valid:总损失: 0.6628 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第85/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 1.8702 准确率: 0.8119
# Time elapsed 6s
# valid:总损失: 0.6357 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第86/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 1.8230 准确率: 0.7525
# Time elapsed 6s
# valid:总损失: 0.3560 准确率: 0.8684
# Optimizer learing rate : 0.0100000
#
# 正在进行第87/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 1.6529 准确率: 0.8218
# Time elapsed 6s
# valid:总损失: 0.0716 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第88/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 2.2910 准确率: 0.8317
# Time elapsed 6s
# valid:总损失: 0.1947 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第89/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 2.3299 准确率: 0.8317
# Time elapsed 6s
# valid:总损失: 0.1975 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第90/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 1.4642 准确率: 0.9109
# Time elapsed 6s
# valid:总损失: 0.4343 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第91/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 0.7274 准确率: 0.8812
# Time elapsed 6s
# valid:总损失: 0.0462 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第92/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 1.2409 准确率: 0.8614
# Time elapsed 6s
# valid:总损失: 0.3390 准确率: 0.8947
# Optimizer learing rate : 0.0100000
#
# 正在进行第93/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 0.3021 准确率: 0.9406
# Time elapsed 6s
# valid:总损失: 0.2969 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第94/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 0.7247 准确率: 0.9208
# Time elapsed 6s
# valid:总损失: 0.4778 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第95/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 0.7999 准确率: 0.8911
# Time elapsed 6s
# valid:总损失: 0.5518 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 正在进行第96/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 0.4127 准确率: 0.9109
# Time elapsed 6s
# valid:总损失: 0.0548 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第97/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 1.1022 准确率: 0.9010
# Time elapsed 6s
# valid:总损失: 0.3763 准确率: 0.9737
# Optimizer learing rate : 0.0100000
#
# 正在进行第98/99轮训练
# ------------------------------
# Time elapsed 6s
# train:总损失: 0.9319 准确率: 0.8416
# Time elapsed 6s
# valid:总损失: 0.1931 准确率: 0.9474
# Optimizer learing rate : 0.0100000
#
# 正在进行第99/99轮训练
# ------------------------------
# Time elapsed 7s
# train:总损失: 1.0774 准确率: 0.8614
# Time elapsed 7s
# valid:总损失: 0.3946 准确率: 0.9211
# Optimizer learing rate : 0.0100000
#
# 总训练时长:7m 3s
# 最好的准确率:1.000000

# %% [markdown]
# ## 加载训练好的模型

# %%
model_ft,input_size = initialize_model(model_name,102,feature_extract)

# GPU模式
model_ft = model_ft.to(device)

# 保存文件的目录+名字
filename='C:\\Users\\22148\\Desktop\\Recognition of medicine\\Asunne2.pth'

# 加载模型
Asunne = torch.load(filename)
best_acc = Asunne['best_acc']
model_ft.load_state_dict(Asunne['state_dict'])
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## 测试数据预处理
# - 测试数据处理方法需要跟训练的一致
# - crop操作的目的是保证输入的大小一致
# - 标准化操作是必须的，用跟训练数据相同的mean和std，但是需要注意一点训练数据是在0-1上进行标准化，所以测试数据也需要归一化
# - PyTorch中颜色通道是第一个维度，跟很多工具包不一样，需要转换

# %%
# def process_image(image_path):
#     # 读取测试数据
#     img = Image.open(image_path)
#     # Resize,thumbnail方法只能进行缩小，所以进行了判断
#     if img.size[0] > img.size[1]:
#         img.thumbnail((10000,256))
#     else:
#         img.thumbnail((256,10000))
#     # Crop操作
#     left_margin = (img.width-224)/2
#     bottom_margin = (img.height-224)/2
#     right_margin = left_margin + 224
#     top_margin = bottom_margin + 224
#     img = img.crop((left_margin,bottom_margin,right_margin,top_margin))
#     # 相同的预处理操作
#     img = np.array(img)/255
#     mean = np.array([0.485,0.456,0.406])# provided mean
#     std = np.array([0.229,0.224,0.225])# proviede std
#     img = (img-mean)/std
    
#     # 注意颜色通道应该放在第一个位置
#     img = img.transpose((2,0,1))# transpose更改通道位置 位置上进行更改(0,1,2)->(2,0,1)
    
#     return img

# %%
def imshow(image,ax=None,title=None):
    """展示数据"""
    if ax is None:
        fig,ax = plt.subplots()
    
    # 颜色通道还原
    image = np.array(image).transpose((1,2,0))
    
    # 预处理操作
    mean = np.array([0.485,0.456,0.406])
    std = np.array([0.229,0.224,0.225])
    image = std * image + mean
    
    ax.set_title(title)
    ax.imshow(image)
    
    return ax

# %%
# image_path = data_dir+'/test/微信图片_20230120030856.jpg' # 测试图像存放的位置
# img = process_image(image_path)
# imshow(img)

# %%
# # 得到一个batch的测试数据
dataiter = iter(dataloaders['valid'])
images,labels = dataiter.__next__()

model_ft.eval()

# 如果在GPU上进行训练，贼将数据放进GPU
if train_on_gpu:
    output = model_ft(images.cuda())
else:
    output = model_ft(images)
    
# 可以输出一下output.shape观察结果,应为torch.size([x,y]) 其中x表示batch的数据量，y表示分类的总个数

# %% [markdown]
# ## 得到概率最大的那个

# %%
_, preds_tensor = torch.max(output,1)
preds = np.squeeze(preds_tensor.numpy() if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy()))
preds
# Out:
# array([2, 0, 3, 4, 2, 4, 2, 3], dtype=int64)

# %%
fig = plt.figure(figsize=(20,20))
columns = 4
rows = 2

for idx in range(columns*rows):
    ax = fig.add_subplot(rows,columns,idx+1,xticks=[],yticks=[])
    plt.imshow(im_convert(images[idx]))
    ax.set_title("{0}({1})".format(medicines_to_name[str(preds[idx]+1)], medicines_to_name[str(labels[idx].item()+1)]),
                color=("green" if medicines_to_name[str(preds[idx]+1)]==medicines_to_name[str(labels[idx].item()+1)] else "red"))
plt.show()
